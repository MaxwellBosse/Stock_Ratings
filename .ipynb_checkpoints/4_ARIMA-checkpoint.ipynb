# %%
#!pip install pmdarima
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from statsmodels.tsa.seasonal import STL
from statsmodels.tsa.stattools import adfuller
import tensorflow as tf
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.arima_model import ARIMA

from statsmodels.tsa.arima_model import ARIMA, ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller  
pd.set_option('display.float_format', lambda x: '%.3f' % x)
from pmdarima.arima import auto_arima
# %matplotlib inline
from sklearn.metrics import mean_squared_error, mean_absolute_error

import warnings
warnings.simplefilter(action="ignore")
import math

# %%
ticker = 'DOCU'
df = pd.read_csv(f'data/{ticker}_stock_data.csv', index_col = 'Unnamed: 0')
df.index = pd.to_datetime(df.index)
series = df[['4. close']]

# %%
#Function to determine if data is stationary 

def test_stationarity(series, window=365):

    #get the rolling mean and rolling standard deviation
    rol_mean = series.rolling(window).mean()
    rol_std = series.rolling(window).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    closing = plt.plot(series, color='blue',label='Closing Price')
    mean = plt.plot(rol_mean, color='purple', label='Rolling Mean')
    std = plt.plot(rol_std, color='red', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Stock Price, Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Dickey-Fuller Test:')
    df = adfuller(series, autolag='AIC', maxlag = 20 )
    df_results = pd.Series(df[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
    for key,value in df[4].items():
        df_results['Critical Value (%s)'%key] = value
    pvalue = df[1]
    #https://thepythonguru.com/python-string-formatting/
    if pvalue < 0.05:
        print('p-value = %.4f. The series is likely stationary.' % pvalue)
    else:
        print('p-value = %.4f. The series is likely non-stationary.' % pvalue)
    
    print(df_results)

# %%
test_stationarity(series)
# Out:
# Dickey-Fuller Test:
# p-value = 0.9983. The series is likely non-stationary.
# Test Statistic                  1.784
# p-value                         0.998
# Number of Lags Used            10.000
# Number of Observations Used   672.000
# Critical Value (1%)            -3.440
# Critical Value (5%)            -2.866
# Critical Value (10%)           -2.569
# dtype: float64

# %%
series_diff = series.diff()
series_diff = series_diff.dropna()

# %%
test_stationarity(series_diff)
# Out:
# Dickey-Fuller Test:
# p-value = 0.0000. The series is likely stationary.
# Test Statistic                 -5.135
# p-value                         0.000
# Number of Lags Used            20.000
# Number of Observations Used   661.000
# Critical Value (1%)            -3.440
# Critical Value (5%)            -2.866
# Critical Value (10%)           -2.569
# dtype: float64

# %%
plot_acf(series_diff)
plt.xlabel('Lags (Days)')
plt.show()

# %%
plot_pacf(series_diff)
plt.xlabel('Lags (Days)')
plt.show()

# %%
print(f'Number of observations: {len(series)}')
print(f'Number of training observations: {round(len(series) * 0.90)}')
print(f'Number of testing observations: {len(series) - round(len(series) * 0.90)}')
# Out:
# Number of observations: 683
# Number of training observations: 615
# Number of testing observations: 68

# %%
plot_axis = len(series)
plot_axis
# Out:
# 683

# %%
split_index = round(len(series) * 0.90) +1
split_index
# Out:
# 616

# %%
train = series.iloc[:split_index,]
test = series.iloc[split_index:,]

# %%
#Get EOY label for plot
index_ = [pd.to_datetime(date, format='%Y').date() 
        for date in pd.date_range(df.index[0], df.index[-1], freq="Y")]

# %%
plt.figure(figsize=(16, 8))
plt.plot(train, c='blue')
plt.plot(test, c='orange')
plt.xticks(index_, rotation = 90);

# %%
#Run auto Arima model to determine best order

model_autoARIMA = auto_arima(train, start_p=0, start_q=0, 
                             test='adf',      #find d
                      max_p=3, max_q=3,       #set max for p and q
                      m=1,                    # freq for series
                      d=None,                 # model determine 'd'
                      seasonal=False,         
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3384.297, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3370.379, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3366.233, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3386.711, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3366.664, Time=0.10 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3364.710, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3355.836, Time=0.12 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3356.439, Time=0.19 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=3356.179, Time=0.20 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=3359.006, Time=0.12 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3354.663, Time=0.14 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3360.843, Time=0.06 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=3356.426, Time=0.25 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=3359.193, Time=0.07 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=3358.426, Time=0.43 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=3359.551, Time=0.06 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0] intercept
# Total fit time: 1.960 seconds

# %%
model_autoARIMA.order
# Out:
# (2, 1, 1)

# %%
print(model_autoARIMA.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  616
# Model:               SARIMAX(2, 1, 1)   Log Likelihood               -1672.332
# Date:                Fri, 22 Jan 2021   AIC                           3354.663
# Time:                        18:30:52   BIC                           3376.772
# Sample:                             0   HQIC                          3363.260
#                                 - 616
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1117      0.051      2.204      0.028       0.012       0.211
# ar.L1          0.8826      0.067     13.168      0.000       0.751       1.014
# ar.L2         -0.2368      0.016    -14.958      0.000      -0.268      -0.206
# ma.L1         -0.7262      0.071    -10.291      0.000      -0.865      -0.588
# sigma2        13.4692      0.215     62.555      0.000      13.047      13.891
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             38013.59
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):              11.84   Skew:                             2.77
# Prob(H) (two-sided):                  0.00   Kurtosis:                        41.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model_autoARIMA.plot_diagnostics(figsize = (16, 8))
plt.show()

# %% [markdown]
# Interpretting the residual plots from autoARIMA
#
# - Standardized Residual - Massive increase in variance as we move right
# - Histogram shows that we have a normal distirbution
# - Distribution appears skewed at the ends
# - ACF plot shows little pattern in residual errors

# %%
model = ARIMA(train, order = model_autoARIMA.order)
fitted = model.fit()
print(fitted.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:             D.4. close   No. Observations:                  615
# Model:                 ARIMA(2, 1, 1)   Log Likelihood               -1672.332
# Method:                       css-mle   S.D. of innovations              3.670
# Date:                Fri, 22 Jan 2021   AIC                           3354.663
# Time:                        18:30:53   BIC                           3376.772
# Sample:                             1   HQIC                          3363.260
#
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.3154      0.115      2.750      0.006       0.091       0.540
# ar.L1.D.4. close     0.8826      0.099      8.955      0.000       0.689       1.076
# ar.L2.D.4. close    -0.2368      0.039     -6.034      0.000      -0.314      -0.160
# ma.L1.D.4. close    -0.7262      0.096     -7.541      0.000      -0.915      -0.537
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.8635           -0.8661j            2.0550           -0.0692
# AR.2            1.8635           +0.8661j            2.0550            0.0692
# MA.1            1.3770           +0.0000j            1.3770            0.0000
# -----------------------------------------------------------------------------

# %%
# Forecast
fc, se, conf = fitted.forecast(len(test), alpha=0.05)  # 95% confidence
fc_series = pd.Series(fc, index=test.index)

plt.figure(figsize=(16,8))
plt.plot(train, label='Training Data')
plt.plot(test, color = 'blue', label='Testing Data')
plt.plot(fc_series, color = 'orange',label='Predicted Stock Price')

plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend(loc='best', fontsize=16)
plt.show()

# %%
#Models Maximum Prediction
fc_series.max()
# Out:
# 258.2421540519849

# %%
#Models Minimum Prediction
fc_series.min()
# Out:
# 238.71681630623334

# %%
# report performance
mse = mean_squared_error(test, fc)
print('MSE: '+ str(mse))
mae = mean_absolute_error(test, fc)
print('MAE: '+str (mae))
rmse = math.sqrt(mean_squared_error(test, fc))
print('RMSE: '+str (rmse))
# Out:
# MSE: 521.8508528501658
# MAE: 19.62929365494149
# RMSE: 22.844055087706426
